# %% [markdown]
# ## Wallaroo Dashboard Metrics Retrieval Tutorial
#
# The following tutorial demonstrates using the Wallaroo MLOps API to retrieve Wallaroo metrics data.  These requests are compliant with Prometheus API endpoints.
#
# This tutorial is split into two sections:
#
# * Inference Data Generation:  This section creates Wallaroo pipeline and inference requests to generate the log files and other data.
# * Wallaroo Dashboard Metrics Retrieval via the Wallaroo MLOps API:  Details the Wallaroo MLOps API metrics retrieval endpoints and provides a demonstration of retrieving metrics data.
#
# ### Prerequisites
#
# This tutorial assumes the following:
#
# * A Wallaroo Ops environment is installed.
# * The Wallaroo SDK is installed.  These examples use the Wallaroo SDK to generate the initial inferences information for the metrics requests.

# %% [markdown]
# ## Inference Data Generation
#
# This part of the tutorial generates the inference results used for the rest of the tutorial.
#
# ### Import libraries
#
# The first step is to import the libraries required.

# %%
import json
import numpy as np
import pandas as pd

import pytz
import datetime

import requests
from requests.auth import HTTPBasicAuth

import wallaroo

# %% [markdown]
# ### Connect to the Wallaroo Instance
#
# A connection to Wallaroo is established via the Wallaroo client.  The Python library is included in the Wallaroo install and available through the Jupyter Hub interface provided with your Wallaroo environment.
#
# This is accomplished using the `wallaroo.Client()` command, which provides a URL to grant the SDK permission to your specific Wallaroo environment.  When displayed, enter the URL into a browser and confirm permissions.  Store the connection into a variable that can be referenced later.
#
# If logging into the Wallaroo instance through the internal JupyterHub service, use `wl = wallaroo.Client()`.  For more information on Wallaroo Client settings, see the [Client Connection guide](https://docs.wallaroo.ai/wallaroo-developer-guides/wallaroo-sdk-guides/wallaroo-sdk-essentials-guide/wallaroo-sdk-essentials-client/).

# %%
wl = wallaroo.Client(api_endpoint="https://autoscale-uat-gcp.wallaroo.dev/", 
                     auth_type="sso")
# Out:
# Please log into the following URL in a web browser:
#
# 	https://autoscale-uat-gcp.wallaroo.dev/auth/realms/master/device?user_code=RLEL-LSWU
#
# Login successful!

# %%
model_name = "ccfraud-model"
model_file_name = "./models/ccfraud.onnx"

# %% [markdown]
# The following queries are available for resource consumption.
#
# #### Storage Resources
#
# | Name | Query |
# |---|---|
# | Get the total size of the minio volume (used to keep models and orch data) | `kubelet_volume_stats_capacity_bytes{persistentvolumeclaim="minio"}` |
# | Get the total size of the plateau volume (used to keep the inference logs) | `kubelet_volume_stats_capacity_bytes{persistentvolumeclaim="plateau-managed-disk"}` |
# | Get the total models storage | `sum(max by(sha) (model_bytes))` |
# | Get the total size of the all the pipeline files by pipeline (w/o pipeline_version) | `sum by(pipeline) (pipeline_models_bytes)` |
# | Get the total size of all the pipeline files by pipeline AND pipeline_version | `sum by(pipeline, pipeline_version) (pipeline_models_bytes)` |
# | Get the total size of all the orchestrations by orchestration AND id | `sum by(id, orchestration) (orchestration_bytes)` |
# | Get the plateau topic storage usage by topic name | `topic_bytes{topic="<topic_name>"}` |
# | Get the used plateau (log) storage | `sum (topic_bytes)` |
#
# #### CPU and Memory Resources
#
# | Name |  Parameterized Query | Example Query |
# |---|---|---|
# | Total allocated CPU resources (cluster-wide), Current point in time | `sum(kube_node_status_capacity{resource="cpu"})` | `sum(kube_node_status_capacity{resource="cpu"})` |
# | Total allocated CPU resources (cluster-wide), Average over some time  | `avg_over_time(sum(kube_node_status_capacity{resource="cpu"})[rangeVector])` | `avg_over_time(sum(kube_node_status_capacity{resource="cpu"})[5m:15s])` |
# | Used CPU resources (cluster wide) Current point in time | `sum(rate(container_cpu_usage_seconds_total[{time_interval}]))` | `sum(rate(container_cpu_usage_seconds_total[5m]))` |
# | Used CPU resources (cluster wide) Average over some time | `avg_over_time(sum(rate(container_cpu_usage_seconds_total[{time_interval}]))[rangeVector])` | `avg_over_time(sum(rate(container_cpu_usage_seconds_total[5m]))[5m:15s])` |
# | Total CPU requests by wallaroo workload | `sum(kube_pod_container_resource_requests{resource="cpu",app_kubernetes_io_instance="wallaroo"})` | `sum(kube_pod_container_resource_requests{resource="cpu",app_kubernetes_io_instance="wallaroo"})` |
# | Total CPU limits by wallaroo workload | `sum(kube_pod_container_resource_limits{resource="cpu",app_kubernetes_io_instance="wallaroo"})` | `sum(kube_pod_container_resource_limits{resource="cpu",app_kubernetes_io_instance="wallaroo"})` |
# | Total allocated Memory resource (cluster-wide) Current point in time | `sum(kube_node_status_capacity{resource="memory"})` | `sum(kube_node_status_capacity{resource="memory"})` |
# | Total allocated Memory resource Average over some time | `avg_over_time(sum(kube_node_status_capacity{resource="memory"})[rangeVector])` | `avg_over_time(sum(kube_node_status_capacity{resource="memory"})[5m:15s])` |
# | Used Memory resources (cluster-wide) Current point in time | `sum(container_memory_usage_bytes)` | `sum(container_memory_usage_bytes)` |
# | Used Memory resources (cluster-wide) Average over some time. | `avg_over_time(sum(container_memory_usage_bytes)[rangeVector])` | `avg_over_time(sum(container_memory_usage_bytes)[5m:15s])` |
# | Total Memory requests by wallaroo workload | `sum(kube_pod_container_resource_requests{resource="memory",app_kubernetes_io_instance="wallaroo"})` | `sum(kube_pod_container_resource_requests{resource="memory",app_kubernetes_io_instance="wallaroo"})` |
# | Total Memory limits by wallaroo workload | `sum(kube_pod_container_resource_limits{resource="memory", app_kubernetes_io_instance="wallaroo"})` | `sum(kube_pod_container_resource_limits{resource="memory", app_kubernetes_io_instance="wallaroo"})` |
#
# #### GPU Resources
#
# | Name |  Parameterized Query |
# |---|---|
# | Total GPU in use by pods resources | `sum(kube_pod_container_resource_limits{resource=~"nvidia_com_gpu\|qualcomm_com_qaic",app_kubernetes_io_instance="wallaroo"})` |
# | Total GPU allocated in the cluster | `sum(kube_node_status_capacity{resource=~"nvidia_com_gpu\|qualcomm_com_qaic"})` |
#
# #### 7 Day Average Queries
#
# The following queries are targeted for average results over a 7 day period.
#
# | Name |  Parameterized Query | Example Query |
# |---|---|---|
# | Memory requests | `avg_over_time(sum(kube_pod_container_resource_requests{resource="memory",app_kubernetes_io_instance="wallaroo"})[7d:])` |
# | CPU requests | `avg_over_time(sum(kube_pod_container_resource_requests{resource="cpu",app_kubernetes_io_instance="wallaroo"})[7d:])` |
# | CPU utilization (percentage) for a given pipeline | `avg_over_time(sum(rate(container_cpu_usage_seconds_total{namespace="<pipeline namespace>"}[5m]))[7d:]) / sum(kube_pod_container_resource_requests{namespace="<pipeline namespace>",resource="cpu"}) * 100` | `avg_over_time(sum(rate(container_cpu_usage_seconds_total{namespace="sample-pipeline-114"}[5m]))[7d:]) / sum(kube_pod_container_resource_requests{namespace="sample-pipeline-114",resource="cpu"}) * 100` |
#  | Memory utilization (percentage) | `avg_over_time(sum(container_memory_usage_bytes{namespace="<pipeline namespace>"})[7d:]) / sum(kube_pod_container_resource_requests{namespace="<pipeline namespace>", resource="memory"}) * 100` | `avg_over_time(sum(container_memory_usage_bytes{namespace="sample-pipeline-114"})[7d:]) / sum(kube_pod_container_resource_requests{namespace="sample-pipeline-114", resource="memory"}) * 100` |

# %% [markdown]
# ### Utilization Query Tests

# %%
#| Get the total size of the minio volume (used to keep models and orch data) | `kubelet_volume_stats_capacity_bytes{persistentvolumeclaim="minio"}` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'kubelet_volume_stats_capacity_bytes{persistentvolumeclaim="minio"}'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success',
#  'data': {'resultType': 'vector',
#   'result': [{'metric': {'__name__': 'kubelet_volume_stats_capacity_bytes',
#      'beta_kubernetes_io_arch': 'amd64',
#      'beta_kubernetes_io_instance_type': 'e2-standard-8',
#      'beta_kubernetes_io_os': 'linux',
#      'cloud_google_com_gke_boot_disk': 'pd-balanced',
#      'cloud_google_com_gke_container_runtime': 'containerd',
#      'cloud_google_com_gke_cpu_scaling_level': '8',
#      'cloud_google_com_gke_logging_variant': 'DEFAULT',
#      'cloud_google_com_gke_max_pods_per_node': '110',
#      'cloud_google_com_gke_memory_gb_scaling_level': '32',
#      'cloud_google_com_gke_nodepool': 'persistent',
#      'cloud_google_com_gke_os_distribution': 'cos',
#      'cloud_google_com_gke_provisioning': 'standard',
#      'cloud_google_com_gke_stack_type': 'IPV4',
#      'cloud_google_com_machine_family': 'e2',
#      'cloud_google_com_private_node': 'false',
#      'failure_domain_beta_kubernetes_io_region': 'us-central1',
#      'failure_domain_beta_kubernetes_io_zone': 'us-central1-c',
#      'instance': 'gke-autoscale-uat-gcp-persistent-e78fe29f-ul3y',
#      'job': 'kubernetes-nodes',
#      'kubernetes_io_arch': 'amd64',
#      'kubernetes_io_hostname': 'gke-autoscale-uat-gcp-persistent-e78fe29f-ul3y',
#      'kubernetes_io_os': 'linux',
#      'namespace': 'wallaroo',
#      'node_kubernetes_io_instance_type': 'e2-standard-8',
#      'persistentvolumeclaim': 'minio',
#      'topology_gke_io_zone': 'us-central1-c',
#      'topology_kubernetes_io_region': 'us-central1',
#      'topology_kubernetes_io_zone': 'us-central1-c',
#      'wallaroo_ai_node_purpose': 'persistent'},
#     'value': [1762288548.641, '685832282112']}]}}

# %% [markdown]
# | Get the total size of the plateau volume (used to keep the inference logs) | `kubelet_volume_stats_capacity_bytes{persistentvolumeclaim="plateau-managed-disk"}` |

# %%
#| Get the total size of the plateau volume (used to keep the inference logs) | `kubelet_volume_stats_capacity_bytes{persistentvolumeclaim="plateau-managed-disk"}` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'kubelet_volume_stats_capacity_bytes{persistentvolumeclaim="plateau-managed-disk"}'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success',
#  'data': {'resultType': 'vector',
#   'result': [{'metric': {'__name__': 'kubelet_volume_stats_capacity_bytes',
#      'beta_kubernetes_io_arch': 'amd64',
#      'beta_kubernetes_io_instance_type': 'e2-standard-8',
#      'beta_kubernetes_io_os': 'linux',
#      'cloud_google_com_gke_boot_disk': 'pd-balanced',
#      'cloud_google_com_gke_container_runtime': 'containerd',
#      'cloud_google_com_gke_cpu_scaling_level': '8',
#      'cloud_google_com_gke_logging_variant': 'DEFAULT',
#      'cloud_google_com_gke_max_pods_per_node': '110',
#      'cloud_google_com_gke_memory_gb_scaling_level': '32',
#      'cloud_google_com_gke_nodepool': 'persistent',
#      'cloud_google_com_gke_os_distribution': 'cos',
#      'cloud_google_com_gke_provisioning': 'standard',
#      'cloud_google_com_gke_stack_type': 'IPV4',
#      'cloud_google_com_machine_family': 'e2',
#      'cloud_google_com_private_node': 'false',
#      'failure_domain_beta_kubernetes_io_region': 'us-central1',
#      'failure_domain_beta_kubernetes_io_zone': 'us-central1-c',
#      'instance': 'gke-autoscale-uat-gcp-persistent-e78fe29f-ul3y',
#      'job': 'kubernetes-nodes',
#      'kubernetes_io_arch': 'amd64',
#      'kubernetes_io_hostname': 'gke-autoscale-uat-gcp-persistent-e78fe29f-ul3y',
#      'kubernetes_io_os': 'linux',
#      'namespace': 'wallaroo',
#      'node_kubernetes_io_instance_type': 'e2-standard-8',
#      'persistentvolumeclaim': 'plateau-managed-disk',
#      'topology_gke_io_zone': 'us-central1-c',
#      'topology_kubernetes_io_region': 'us-central1',
#      'topology_kubernetes_io_zone': 'us-central1-c',
#      'wallaroo_ai_node_purpose': 'persistent'},
#     'value': [1762288550.576, '105089261568']}]}}

# %% [markdown]
# | Get the total models storage | `sum(max by(sha) (model_bytes))` |

# %%
#| Get the total models storage | `sum(max by(sha) (model_bytes))` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'sum(max by(sha) (model_bytes))'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success',
#  'data': {'resultType': 'vector',
#   'result': [{'metric': {}, 'value': [1762288601.487, '476090674588']}]}}

# %% [markdown]
# | Get the total size of the all the pipeline files by pipeline (w/o pipeline_version) | `sum by(pipeline) (pipeline_models_bytes)` |

# %%
#| Get the total models storage | `sum by(pipeline) (pipeline_models_bytes)` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'sum by(pipeline) (pipeline_models_bytes)'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success',
#  'data': {'resultType': 'vector',
#   'result': [{'metric': {'pipeline': 'retina-face-resnet50-pipe'},
#     'value': [1762288787.385, '109105123']},
#    {'metric': {'pipeline': 'logging-pipeline-850802'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-pk100'},
#     'value': [1762288787.385, '556622']},
#    {'metric': {'pipeline': 'tinyllama-openai'},
#     'value': [1762288787.385, '48146516335']},
#    {'metric': {'pipeline': 'auto-conversion-xgboost-classification-pipeline-112261'},
#     'value': [1762288787.385, '285313']},
#    {'metric': {'pipeline': 'retail-inv-openvino'},
#     'value': [1762288787.385, '77858235']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-142849'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'house-price-predictor-drift'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'byop-vllm-100cb'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'retail-inv-cuda'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'whisper-byop-jcw'},
#     'value': [1762288787.385, '5119982767']},
#    {'metric': {'pipeline': 'keras-sequential-single-io'},
#     'value': [1762288787.385, '2224335833']},
#    {'metric': {'pipeline': 'image-pipeline-fixed-arr'},
#     'value': [1762288787.385, '7408609922']},
#    {'metric': {'pipeline': 'edge-inline-replacement-demon'},
#     'value': [1762288787.385, '171121']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llama-3dot1-pipeline'},
#     'value': [1762288787.385, '32301936016']},
#    {'metric': {'pipeline': 'simpleorchestrationpipeline-jcw'},
#     'value': [1762288787.385, '451636']},
#    {'metric': {'pipeline': 'llama-rag-pipeline'},
#     'value': [1762288787.385, '995954666']},
#    {'metric': {'pipeline': 'auto-packaging-byop-llamacpp-150240'},
#     'value': [1762288787.385, '534533017']},
#    {'metric': {'pipeline': 'whse-a-demand-forecast'},
#     'value': [1762288787.385, '18730505']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-pk'},
#     'value': [1762288787.385, '451636']},
#    {'metric': {'pipeline': 'python-onnx-pipeline'},
#     'value': [1762288787.385, '9285872940']},
#    {'metric': {'pipeline': 'whisper-hf-byop-jcw'},
#     'value': [1762288787.385, '5119993007']},
#    {'metric': {'pipeline': 'byop-vllm-vanilla'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'yolo8demonstration'},
#     'value': [1762288787.385, '12823491']},
#    {'metric': {'pipeline': 'mock-viability-pipeline'},
#     'value': [1762288787.385, '535369718']},
#    {'metric': {'pipeline': 'e2e-metrics-test'},
#     'value': [1762288787.385, '19894854']},
#    {'metric': {'pipeline': 'logs-pipeline'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'tinyllama-31-8b-vllm-egde'},
#     'value': [1762288787.385, '19804819514']},
#    {'metric': {'pipeline': 'mac-keras-single-io-example-pipeline'},
#     'value': [1762288787.385, '2393439193']},
#    {'metric': {'pipeline': 'mock-viability-pipeline-pk-3'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'alohapipeline'},
#     'value': [1762288787.385, '4269411']},
#    {'metric': {'pipeline': 'ccfraudpipeline'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'house-price-predictor'},
#     'value': [1762288787.385, '451636']},
#    {'metric': {'pipeline': 'llama-pipe'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llama-openai'},
#     'value': [1762288787.385, '57952137782']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs-2'},
#     'value': [1762288787.385, '738534342']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo1'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'rum-assay-nan-jcw'},
#     'value': [1762288787.385, '1253591640']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-dynbatchedge'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-error'},
#     'value': [1762288787.385, '9221721160']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb1'},
#     'value': [1762288787.385, '15198246897']},
#    {'metric': {'pipeline': 'lstm-demand-forecast'},
#     'value': [1762288787.385, '19084360']},
#    {'metric': {'pipeline': 'auto-packaging-byop-llamacpp-814365'},
#     'value': [1762288787.385, '534533017']},
#    {'metric': {'pipeline': 'noop-pipeline-593114'},
#     'value': [1762288787.385, '1031763158']},
#    {'metric': {'pipeline': 'image-pipeline-b64'},
#     'value': [1762288787.385, '22225830048']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-openvino1'},
#     'value': [1762288787.385, '3797551676']},
#    {'metric': {'pipeline': 'mac-keras-single-io-p1'},
#     'value': [1762288787.385, '4629888946']},
#    {'metric': {'pipeline': 'logging-pipeline-278379'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'resnet-pipeline'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo-swap2'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'bench-aloha-pipeline'},
#     'value': [1762288787.385, '1421061']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-jcw'},
#     'value': [1762288787.385, '451636']},
#    {'metric': {'pipeline': 'byop-tinyllama-cutom-vllmedgeyns'},
#     'value': [1762288787.385, '11392345928']},
#    {'metric': {'pipeline': 'whisper-hf-arm'},
#     'value': [1762288787.385, '1042414767']},
#    {'metric': {'pipeline': 'image-pipeline-list'},
#     'value': [1762288787.385, '7408609922']},
#    {'metric': {'pipeline': 'llamacpp-pipe-ynstest'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'house-price-with-challengers'},
#     'value': [1762288787.385, '782440']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-pk3'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'rum-assay'},
#     'value': [1762288787.385, '1253591638']},
#    {'metric': {'pipeline': 'simpleorchestrationtutorial'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'preethi2-retail-inv-tracker-edge-obs'},
#     'value': [1762288787.385, '738534342']},
#    {'metric': {'pipeline': 'edgebiolabspipeline'},
#     'value': [1762288787.385, '7775971']},
#    {'metric': {'pipeline': 'llama-cpp'},
#     'value': [1762288787.385, '11335464628']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-3'},
#     'value': [1762288787.385, '529185057']},
#    {'metric': {'pipeline': 'llama'}, 'value': [1762288787.385, '57958701622']},
#    {'metric': {'pipeline': 'replica-scaling-static'},
#     'value': [1762288787.385, '1423137']},
#    {'metric': {'pipeline': 'sleep-passthrough-pipe'},
#     'value': [1762288787.385, '7234865276']},
#    {'metric': {'pipeline': 'whisper-hf-byop-replicatest'},
#     'value': [1762288787.385, '6003694767']},
#    {'metric': {'pipeline': 'ai-screening'},
#     'value': [1762288787.385, '2217187916']},
#    {'metric': {'pipeline': 'llamacppovms'},
#     'value': [1762288787.385, '3797551676']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-ynsv6'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'arrow-test-model-pipeline'},
#     'value': [1762288787.385, '1877792536']},
#    {'metric': {'pipeline': 'whisper-hf-byop'},
#     'value': [1762288787.385, '7882007727']},
#    {'metric': {'pipeline': 'sidekick-replica-static'},
#     'value': [1762288787.385, '6003694767']},
#    {'metric': {'pipeline': 'logging-pipeline-949260'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'demandcurvepipeline'},
#     'value': [1762288787.385, '1051733230']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-jb'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'deployment-status-ccfraud-pipeline-431950'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'logging-pipeline-236223'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'resnetnetpipeline-p10'},
#     'value': [1762288787.385, '167496949']},
#    {'metric': {'pipeline': 'scale-test-fm-2'},
#     'value': [1762288787.385, '3617665969']},
#    {'metric': {'pipeline': 'safeguards-llamacpp-3'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'simpleorchestrationtutorial-jcw'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'pt-unet'}, 'value': [1762288787.385, '62225995']},
#    {'metric': {'pipeline': 'retail-inv-tracker-jetson'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-702016'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'llama-8b'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-arm'},
#     'value': [1762288787.385, '3770507836']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag'},
#     'value': [1762288787.385, '30396493794']},
#    {'metric': {'pipeline': 'crashy-pipeline'},
#     'value': [1762288787.385, '2103462744']},
#    {'metric': {'pipeline': 'auto-packaging-python-fail-646204'},
#     'value': [1762288787.385, '512011018']},
#    {'metric': {'pipeline': 'rx-gender-pipeline'},
#     'value': [1762288787.385, '85156557']},
#    {'metric': {'pipeline': 'edge-pipeline'},
#     'value': [1762288787.385, '224466']},
#    {'metric': {'pipeline': 'deploy-specific-version-434108'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb'},
#     'value': [1762288787.385, '32099755937']},
#    {'metric': {'pipeline': 'logging-pipeline-375742'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'resnetnetpipeline'},
#     'value': [1762288787.385, '689184535']},
#    {'metric': {'pipeline': 'llamacpp-new-pipe-dyn'},
#     'value': [1762288787.385, '7088477742']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo-2'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'test-pipeline'},
#     'value': [1762288787.385, '47145045']},
#    {'metric': {'pipeline': 'rag-pipeline'},
#     'value': [1762288787.385, '9010563378']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs'},
#     'value': [1762288787.385, '2251935381']},
#    {'metric': {'pipeline': 'hf-summarization-pipeline'},
#     'value': [1762288787.385, '9290701800']},
#    {'metric': {'pipeline': 'deployment-status-ccfraud-pipeline-894029'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'deployment-status-ccfraud-pipeline-669117'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-1'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-389182'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'tinyllama-openai-error1'},
#     'value': [1762288787.385, '9221721160']},
#    {'metric': {'pipeline': 'passthrough-vc-test'},
#     'value': [1762288787.385, '497154802']},
#    {'metric': {'pipeline': 'ab-testing-pipeline-931264'},
#     'value': [1762288787.385, '2327']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-egde-yns1'},
#     'value': [1762288787.385, '19804819514']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial'},
#     'value': [1762288787.385, '1129090']},
#    {'metric': {'pipeline': 'llamavllm'},
#     'value': [1762288787.385, '13221146439']},
#    {'metric': {'pipeline': 'auto-conversion-pytorch-multi-io-pipeline-799130'},
#     'value': [1762288787.385, '12211']},
#    {'metric': {'pipeline': 'vgg16-clustering-pipeline'},
#     'value': [1762288787.385, '4057667713']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo'},
#     'value': [1762288787.385, '39596286068']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-532802'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'deploy-specific-version-751387'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'byopllamacpp-safeguards-pegasi-single-2'},
#     'value': [1762288787.385, '3796733804']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb2'},
#     'value': [1762288787.385, '15198246897']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-yns1'},
#     'value': [1762288787.385, '14283735250']},
#    {'metric': {'pipeline': 'yolo8demonstration-openvino'},
#     'value': [1762288787.385, '12823491']},
#    {'metric': {'pipeline': 'image-pipeline-list-arm'},
#     'value': [1762288787.385, '531695223']},
#    {'metric': {'pipeline': 'retail-inv-arm-jet'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'vllm-pipeline-shadow'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'resnetnetpipeline-benchp10'},
#     'value': [1762288787.385, '167496949']},
#    {'metric': {'pipeline': 'scale-test-ya'},
#     'value': [1762288787.385, '7059601261']},
#    {'metric': {'pipeline': 'byopllamacpp'},
#     'value': [1762288787.385, '1388869697']},
#    {'metric': {'pipeline': 'mitch-edge-20250718'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'ab-testing-pipeline-721493'},
#     'value': [1762288787.385, '2327']},
#    {'metric': {'pipeline': 'multi-io-example'},
#     'value': [1762288787.385, '2489']},
#    {'metric': {'pipeline': 'preethi-orch-scale-pipe'},
#     'value': [1762288787.385, '451636']},
#    {'metric': {'pipeline': 'whse-c-demand-forecast'},
#     'value': [1762288787.385, '18678202']},
#    {'metric': {'pipeline': 'alohapipelinejch'},
#     'value': [1762288787.385, '1423137']},
#    {'metric': {'pipeline': 'simpleorchpipeline'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'aloha-pipeline'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop-test'},
#     'value': [1762288787.385, '4459635887']},
#    {'metric': {'pipeline': 'hf-zero-shot-classification-jb'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'bench-big-arrays-pipeline'},
#     'value': [1762288787.385, '608157399']},
#    {'metric': {'pipeline': 'pk-resident-signal-staging-pipeline'},
#     'value': [1762288787.385, '1108593958']},
#    {'metric': {'pipeline': 'safeguardsdemopipe'},
#     'value': [1762288787.385, '9751444190']},
#    {'metric': {'pipeline': 'vllm-double-replicas'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-332650'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'recommender-ab-test'},
#     'value': [1762288787.385, '47145045']},
#    {'metric': {'pipeline': 'auto-packaging-keras-multi-io-pipeline-310172'},
#     'value': [1762288787.385, '2225629123']},
#    {'metric': {'pipeline': 'whisper-hf-byop-testshared2'},
#     'value': [1762288787.385, '4459635887']},
#    {'metric': {'pipeline': 'passthrough-vc-fixed-shape-tensor'},
#     'value': [1762288787.385, '497154802']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-327896'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'logging-pipeline-839648'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'llama-pipe-3'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-968262'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'llama3-8b-instruct-llamacpp-v1'},
#     'value': [1762288787.385, '7066974073']},
#    {'metric': {'pipeline': 'logging-pipeline-566299'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'llama-3dot1-8b-pipe'},
#     'value': [1762288787.385, '19826190394']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-5'},
#     'value': [1762288787.385, '529185057']},
#    {'metric': {'pipeline': 'keras-sequential-single-io-jb'},
#     'value': [1762288787.385, '2236818393']},
#    {'metric': {'pipeline': 'scale-test-jb'},
#     'value': [1762288787.385, '7059601261']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-594544'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'logging-pipeline-446586'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'hotswap-vllm'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'tiny-llama-cuda-demo-pipe'},
#     'value': [1762288787.385, '8893653991']},
#    {'metric': {'pipeline': 'auto-conversion-xgboost-booster-pipeline-324973'},
#     'value': [1762288787.385, '23653']},
#    {'metric': {'pipeline': 'logging-pipeline-153932'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-205619'},
#     'value': [1762288787.385, '1421061']},
#    {'metric': {'pipeline': 'shadow-pipeline-554344'},
#     'value': [1762288787.385, '113197']},
#    {'metric': {'pipeline': 'llama3-8b-instruct-llamacpp-t4'},
#     'value': [1762288787.385, '7066974076']},
#    {'metric': {'pipeline': 'alohapipeline-jcw'},
#     'value': [1762288787.385, '2846274']},
#    {'metric': {'pipeline': 'retail-inv-openvino-frcnn'},
#     'value': [1762288787.385, '167496949']},
#    {'metric': {'pipeline': 'scale-test-cp'},
#     'value': [1762288787.385, '3617665970']},
#    {'metric': {'pipeline': 'test-viability-pipeline'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-548655'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'byop-tinyllama-cutom-vllm'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'shadow-pipeline-880880'},
#     'value': [1762288787.385, '113197']},
#    {'metric': {'pipeline': 'auto-packaging-keras-multi-io-pipeline-517349'},
#     'value': [1762288787.385, '2225635465']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-198252'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo-swap1'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'alohapipeline-imp'},
#     'value': [1762288787.385, '1423137']},
#    {'metric': {'pipeline': 'dlrm-click-prediction'},
#     'value': [1762288787.385, '47145045']},
#    {'metric': {'pipeline': 'auto-conversion-pytorch-single-io-pipeline-355420'},
#     'value': [1762288787.385, '7303']},
#    {'metric': {'pipeline': 'edge-hf-summarization'},
#     'value': [1762288787.385, '9290701800']},
#    {'metric': {'pipeline': 'rum-assay-nan'},
#     'value': [1762288787.385, '1373102520']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-663217'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'edge-observability-pipeline'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'keras-sequential-single-io-openvino'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'byop-tinyllama-demo-yns2'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'byopllamacpp-safeguards-pegasi-single-3'},
#     'value': [1762288787.385, '3796733894']},
#    {'metric': {'pipeline': 'mitch-edge-20250718-b'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'summarizer-listener'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llama-pipe-jb'},
#     'value': [1762288787.385, '19846875201']},
#    {'metric': {'pipeline': 'xgb-ranker-pipeline'},
#     'value': [1762288787.385, '835382870']},
#    {'metric': {'pipeline': 'new-edge-inline-replacement'},
#     'value': [1762288787.385, '214380']},
#    {'metric': {'pipeline': 'ttttalohapipeline'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'metrics-retrieval-tutorial-pipeline'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb3'},
#     'value': [1762288787.385, '15198246897']},
#    {'metric': {'pipeline': 'logging-pipeline-242166'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'test-alohapipeline'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'deploy-specific-version-737646'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'noop-pipeline-405143'},
#     'value': [1762288787.385, '1031763158']},
#    {'metric': {'pipeline': 'metrics-retrieval-tutorial-summarization-pipeline'},
#     'value': [1762288787.385, '8191752630']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo-swap3'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'logging-pipeline-443908'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-201371'},
#     'value': [1762288787.385, '1421061']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-2'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'keras-sequential-single-io-jcw'},
#     'value': [1762288787.385, '2236449753']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-374815'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'preethi-retail-inv-tracker-edge-obs'},
#     'value': [1762288787.385, '1477068684']},
#    {'metric': {'pipeline': 'architecture-demonstration-arm'},
#     'value': [1762288787.385, '2628621047']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-jcw-2'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'clip-demo-jcw'},
#     'value': [1762288787.385, '8175170315']},
#    {'metric': {'pipeline': 'prophet-pipeline'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-openvino3'},
#     'value': [1762288787.385, '3791346236']},
#    {'metric': {'pipeline': 'whse-s-demand-forecast'},
#     'value': [1762288787.385, '18815233']},
#    {'metric': {'pipeline': 'safeguards-llamacpp-1'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'cgo-multi-step-pipeline'},
#     'value': [1762288787.385, '1628712335']},
#    {'metric': {'pipeline': 'byopllamacpp-safeguards-pegasi-single'},
#     'value': [1762288787.385, '3796733804']},
#    {'metric': {'pipeline': 'empty-config-lazyadam-pipeline-410913'},
#     'value': [1762288787.385, '68968']},
#    {'metric': {'pipeline': 'auto-packaging-byop-extra-reqs-591104'},
#     'value': [1762288787.385, '607316431']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-845532'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'shadow-pipeline-161803'},
#     'value': [1762288787.385, '113197']},
#    {'metric': {'pipeline': 'whisper-hf-byop-testshared'},
#     'value': [1762288787.385, '4459635887']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-ynsv4'},
#     'value': [1762288787.385, '7141867625']},
#    {'metric': {'pipeline': 'llama-31-8b-pipeline'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'passthrough-test'},
#     'value': [1762288787.385, '497144109']},
#    {'metric': {'pipeline': 'noop-pipeline-402927'},
#     'value': [1762288787.385, '1031763158']},
#    {'metric': {'pipeline': 'empty-config-from-list-pipeline-410913'},
#     'value': [1762288787.385, '68968']},
#    {'metric': {'pipeline': 'auto-packaging-python-fail-252731'},
#     'value': [1762288787.385, '512103178']},
#    {'metric': {'pipeline': 'processing-step-pipe'},
#     'value': [1762288787.385, '1034006032']},
#    {'metric': {'pipeline': 'airplane-detection-pipeline'},
#     'value': [1762288787.385, '7647946']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-akmel'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-dynbatchedge1'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'simpleorchestrationpipeline-jcw-2'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'byop-tinyllama-demo-yns1'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-930939'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'auto-packaging-byop-llamacpp-568890'},
#     'value': [1762288787.385, '534533017']},
#    {'metric': {'pipeline': 'deploy-specific-version-697543'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'safeguards-llamacpp-demo'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'demandcurvepipeline2'},
#     'value': [1762288787.385, '1051733230']},
#    {'metric': {'pipeline': 'byop-tinyllama-demo-yns-cudafix'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'passthrough-vc-flatten-reshape'},
#     'value': [1762288787.385, '497154680']},
#    {'metric': {'pipeline': 'auto-packaging-python-fail-214673'},
#     'value': [1762288787.385, '521995018']},
#    {'metric': {'pipeline': 'auto-packaging-hf-translation-pipeline-324606'},
#     'value': [1762288787.385, '7783113971']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-openvino2'},
#     'value': [1762288787.385, '3791346236']},
#    {'metric': {'pipeline': 'validation-demo-jcw'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-367533'},
#     'value': [1762288787.385, '1421061']},
#    {'metric': {'pipeline': 'ps-xgboost-jcw'},
#     'value': [1762288787.385, '839944522']},
#    {'metric': {'pipeline': 'noop-pipeline-814814'},
#     'value': [1762288787.385, '1031763158']},
#    {'metric': {'pipeline': 'passthrough-vc-test-2'},
#     'value': [1762288787.385, '497154802']},
#    {'metric': {'pipeline': 'tensorflow-lazyadam-pipeline-274014'},
#     'value': [1762288787.385, '68968']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'xgboost-regressor'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llamacppovms1'},
#     'value': [1762288787.385, '3791346236']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-303115'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'edge-low-connection-demonstration'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'shadow-pipeline-849479'},
#     'value': [1762288787.385, '113197']},
#    {'metric': {'pipeline': 'mobilenet-pipeline'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-540652'},
#     'value': [1762288787.385, '1421061']},
#    {'metric': {'pipeline': 'nostart-pipe'},
#     'value': [1762288787.385, '2073733512']},
#    {'metric': {'pipeline': 'llama3-8b-instruct-llamacpp3'},
#     'value': [1762288787.385, '7059601261']},
#    {'metric': {'pipeline': 'byopllamacpp-safeguards'},
#     'value': [1762288787.385, '12159308000']},
#    {'metric': {'pipeline': 'auto-packaging-byop-gpu-578990'},
#     'value': [1762288787.385, '4904469545']},
#    {'metric': {'pipeline': 'byop-tinyllama-demo-yns'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'safeguards-llamacpp-ynsdemo'},
#     'value': [1762288787.385, '1388869697']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-c1000'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-openvino3-imp'},
#     'value': [1762288787.385, '3791346236']},
#    {'metric': {'pipeline': 'scale-test-fm-3'},
#     'value': [1762288787.385, '7059601261']},
#    {'metric': {'pipeline': 'ma-consumptionchanges-stage'},
#     'value': [1762288787.385, '1405225532']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-126534'},
#     'value': [1762288787.385, '1421061']},
#    {'metric': {'pipeline': 'hf-zero-shot-classification-jcw'},
#     'value': [1762288787.385, '5047384331']},
#    {'metric': {'pipeline': 'auto-packaging-byop-157979'},
#     'value': [1762288787.385, '554293631']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-486959'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'auto-packaging-keras-multi-io-pipeline-689980'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'hf-feature-extraction-pipeline-new-v1'},
#     'value': [1762288787.385, '5914817408']},
#    {'metric': {'pipeline': 'assay-demo-tutorial'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-4551-test'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-480975'},
#     'value': [1762288787.385, '1421061']},
#    {'metric': {'pipeline': 'auto-packaging-byop-extra-reqs-174855'},
#     'value': [1762288787.385, '607521231']},
#    {'metric': {'pipeline': 'shadow-pipeline-801466'},
#     'value': [1762288787.385, '113197']},
#    {'metric': {'pipeline': 'preethi-viability-pipeline'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'p1'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'keras-seq-single-io-jb-new'},
#     'value': [1762288787.385, '2236818393']},
#    {'metric': {'pipeline': 'llama-pipe--jb'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop-testshared1'},
#     'value': [1762288787.385, '4459635887']},
#    {'metric': {'pipeline': 'safeguards-llamacpp-2'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'byop-tinyllama-cutom-vllmedge'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'tinyllama3'},
#     'value': [1762288787.385, '8921926634']},
#    {'metric': {'pipeline': 'shadowimagepipelinetest'},
#     'value': [1762288787.385, '767042770']},
#    {'metric': {'pipeline': 'resident-signal-staging-pipeline'},
#     'value': [1762288787.385, '1108594593']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-ynsv5'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'edge-pipeline-classification-cybersecurity'},
#     'value': [1762288787.385, '1423137']},
#    {'metric': {'pipeline': 'byop-tinyllama-cutom-vllmedgeynsjb'},
#     'value': [1762288787.385, '11392345928']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-913986'},
#     'value': [1762288787.385, '1421061']},
#    {'metric': {'pipeline': 'data-optimization'},
#     'value': [1762288787.385, '529389343']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-pk4'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'shadow-pipeline-961739'},
#     'value': [1762288787.385, '113197']},
#    {'metric': {'pipeline': 'house-pipe-openvino'},
#     'value': [1762288787.385, '171121']},
#    {'metric': {'pipeline': 'apiinferenceexamplepipeline'},
#     'value': [1762288787.385, '522549193']},
#    {'metric': {'pipeline': 'auto-packaging-byop-llamacpp-934757'},
#     'value': [1762288787.385, '534533017']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-arm1'},
#     'value': [1762288787.385, '3761189436']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-699333'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'edge-pipeline-ccfraud'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-805593'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'deploy-specific-version-178822'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'auto-packaging-byop-985934'},
#     'value': [1762288787.385, '554088831']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo-swap'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'noop-pipeline-983384'},
#     'value': [1762288787.385, '1031947478']},
#    {'metric': {'pipeline': 'byopllamacpp-safeguard'},
#     'value': [1762288787.385, '1388869697']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-edge'},
#     'value': [1762288787.385, '3796722236']},
#    {'metric': {'pipeline': 'llama3-8b-instruct-llamacpp2'},
#     'value': [1762288787.385, '7059601251']},
#    {'metric': {'pipeline': 'byopllamacpp-safeguards-pegasi-multi'},
#     'value': [1762288787.385, '12159308387']},
#    {'metric': {'pipeline': 'scale-test-fm'},
#     'value': [1762288787.385, '3617665970']},
#    {'metric': {'pipeline': 'tag-keras-ccfraud-pipeline-185327'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-311696'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-pk-2'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-926947'},
#     'value': [1762288787.385, '1421061']},
#    {'metric': {'pipeline': 'edge-low-connection-demonstrationxxx'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'deploy-specific-version-583663'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'retail-inv-ibm'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llama3-8b-instruct-llamacpp-v2'},
#     'value': [1762288787.385, '7066974073']},
#    {'metric': {'pipeline': 'hotswap-vllm-2'},
#     'value': [1762288787.385, '19798143034']},
#    {'metric': {'pipeline': 'deployment-status-ccfraud-pipeline-641845'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'assay-pk-pipe-1000'},
#     'value': [1762288787.385, '440198']},
#    {'metric': {'pipeline': 'retail-inv-arm-cuda'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'byopllamacpp-safeguards-single'},
#     'value': [1762288787.385, '3796733507']},
#    {'metric': {'pipeline': 'edge-pipeline-jb'},
#     'value': [1762288787.385, '111269']},
#    {'metric': {'pipeline': 'apipipeline'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'auto-packaging-keras-multi-io-pipeline-464266'},
#     'value': [1762288787.385, '2236827785']},
#    {'metric': {'pipeline': 'ab-testing-pipeline-851978'},
#     'value': [1762288787.385, '2327']},
#    {'metric': {'pipeline': 'logging-pipeline-909582'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'passthrough-vc-fixed-shape-tensor-test'},
#     'value': [1762288787.385, '497154802']},
#    {'metric': {'pipeline': 'noop-pipeline-227333'},
#     'value': [1762288787.385, '1051792598']},
#    {'metric': {'pipeline': 'whisper-hf-byop-test2'},
#     'value': [1762288787.385, '4459635887']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-885251'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'opik-metric-pipeline'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'auto-packaging-byop-332646'},
#     'value': [1762288787.385, '554088831']},
#    {'metric': {'pipeline': 'auto-packaging-byop-llamacpp-100830'},
#     'value': [1762288787.385, '524753817']},
#    {'metric': {'pipeline': 'pytorch-multi-io-jcw'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'mobilenetpipeline'},
#     'value': [1762288787.385, '593985501']},
#    {'metric': {'pipeline': 'ccfraudpipeline-jcw'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'passthrough-vc-flatten-reshape-test'},
#     'value': [1762288787.385, '497154680']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-4551'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-987498'},
#     'value': [1762288787.385, '1421061']},
#    {'metric': {'pipeline': 'deploy-specific-version-311428'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'ccfraudpipeline01'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'auto-packaging-byop-300490'},
#     'value': [1762288787.385, '554088831']},
#    {'metric': {'pipeline': 'shadow-pipeline-646553'},
#     'value': [1762288787.385, '113197']},
#    {'metric': {'pipeline': 'auto-packaging-xgb-rf-regressor-pipeline-693940'},
#     'value': [1762288787.385, '839811917']},
#    {'metric': {'pipeline': 'sklearn-linear-regression'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'bench-big-arrays-fixed-pipeline'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-745121'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'preethi-assay-test-pipeline'},
#     'value': [1762288787.385, '225818']},
#    {'metric': {'pipeline': 'byop-vllm-l4'}, 'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'auto-packaging-byop-llamacpp-376166'},
#     'value': [1762288787.385, '534533017']},
#    {'metric': {'pipeline': 'shadow-pipeline-329308'},
#     'value': [1762288787.385, '113197']},
#    {'metric': {'pipeline': 'keras-sequential-single-io-bugtest'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'ab-testing-pipeline-232269'},
#     'value': [1762288787.385, '2327']},
#    {'metric': {'pipeline': 'logging-no-validation-pipeline-140699'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'summarizer-listener-yns'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-arm2'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'keras-sequential-single-io-power'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'ab-testing-pipeline-841882'},
#     'value': [1762288787.385, '2327']},
#    {'metric': {'pipeline': 'whse-j-demand-forecast'},
#     'value': [1762288787.385, '18412106']},
#    {'metric': {'pipeline': 'xgb-booster-regression-conversion'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'deploy-specific-version-625384'},
#     'value': [1762288787.385, '1928']},
#    {'metric': {'pipeline': 'async-llama-pipe'},
#     'value': [1762288787.385, '0']},
#    {'metric': {'pipeline': 'llama3-8b-instruct-llamacpp'},
#     'value': [1762288787.385, '7066974078']},
#    {'metric': {'pipeline': 'qualcomm-rag'},
#     'value': [1762288787.385, '16891453360']}]}}

# %% [markdown]
# | Get the total size of all the pipeline files by pipeline AND pipeline_version | `sum by(pipeline, pipeline_version) (pipeline_models_bytes)` |

# %%
#| Get the total size of all the pipeline files by pipeline AND pipeline_version | `sum by(pipeline, pipeline_version) (pipeline_models_bytes)` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'sum by(pipeline, pipeline_version) (pipeline_models_bytes)'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success',
#  'data': {'resultType': 'vector',
#   'result': [{'metric': {'pipeline': 'retina-face-resnet50-pipe',
#      'pipeline_version': '772'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-850802',
#      'pipeline_version': '2205'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-pk100',
#      'pipeline_version': '1854'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '2139'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-conversion-xgboost-classification-pipeline-112261',
#      'pipeline_version': '1619'},
#     'value': [1762288980.294, '285313']},
#    {'metric': {'pipeline': 'retail-inv-openvino', 'pipeline_version': '2040'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-142849',
#      'pipeline_version': '2184'},
#     'value': [1762288980.294, '1928']},
#    {'metric': {'pipeline': 'house-price-predictor-drift',
#      'pipeline_version': '131'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byop-vllm-100cb', 'pipeline_version': '1371'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-cuda', 'pipeline_version': '2054'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-byop-jcw', 'pipeline_version': '645'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'keras-sequential-single-io',
#      'pipeline_version': '2052'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-fixed-arr',
#      'pipeline_version': '1140'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-inline-replacement-demon',
#      'pipeline_version': '533'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns', 'pipeline_version': '723'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-3dot1-pipeline', 'pipeline_version': '1577'},
#     'value': [1762288980.294, '32301936016']},
#    {'metric': {'pipeline': 'whisper-byop-jcw', 'pipeline_version': '665'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'simpleorchestrationpipeline-jcw',
#      'pipeline_version': '93'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-rag-pipeline', 'pipeline_version': '465'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-packaging-byop-llamacpp-150240',
#      'pipeline_version': '2227'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whse-a-demand-forecast',
#      'pipeline_version': '443'},
#     'value': [1762288980.294, '18730505']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1687'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-pk',
#      'pipeline_version': '1777'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'python-onnx-pipeline', 'pipeline_version': '1251'},
#     'value': [1762288980.294, '1031763660']},
#    {'metric': {'pipeline': 'whisper-hf-byop-jcw', 'pipeline_version': '733'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byop-vllm-vanilla', 'pipeline_version': '1416'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'yolo8demonstration', 'pipeline_version': '1863'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '419'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'e2e-metrics-test', 'pipeline_version': '1366'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logs-pipeline', 'pipeline_version': '1449'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-31-8b-vllm-egde',
#      'pipeline_version': '1547'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mac-keras-single-io-example-pipeline',
#      'pipeline_version': '180'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline-pk-3',
#      'pipeline_version': '937'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'alohapipeline', 'pipeline_version': '782'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'ccfraudpipeline', 'pipeline_version': '21'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-predictor', 'pipeline_version': '106'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-pipe', 'pipeline_version': '977'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-openai', 'pipeline_version': '1790'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs-2',
#      'pipeline_version': '15'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo1',
#      'pipeline_version': '1200'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns', 'pipeline_version': '726'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '369'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'rum-assay-nan-jcw', 'pipeline_version': '809'},
#     'value': [1762288980.294, '1253591640']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-dynbatchedge',
#      'pipeline_version': '824'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-error',
#      'pipeline_version': '1761'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-openai', 'pipeline_version': '1766'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-dynbatchedge',
#      'pipeline_version': '826'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb1',
#      'pipeline_version': '1829'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'lstm-demand-forecast', 'pipeline_version': '457'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-packaging-byop-llamacpp-814365',
#      'pipeline_version': '2229'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'noop-pipeline-593114', 'pipeline_version': '1226'},
#     'value': [1762288980.294, '1031763158']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1108'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-openvino1',
#      'pipeline_version': '1876'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mac-keras-single-io-p1',
#      'pipeline_version': '578'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'alohapipeline', 'pipeline_version': '1196'},
#     'value': [1762288980.294, '1423137']},
#    {'metric': {'pipeline': 'house-price-predictor', 'pipeline_version': '109'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'e2e-metrics-test', 'pipeline_version': '1368'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-278379',
#      'pipeline_version': '2212'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'resnet-pipeline', 'pipeline_version': '547'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo-swap2',
#      'pipeline_version': '1521'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'bench-aloha-pipeline', 'pipeline_version': '320'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-jcw',
#      'pipeline_version': '738'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byop-tinyllama-cutom-vllmedgeyns',
#      'pipeline_version': '1594'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-arm', 'pipeline_version': '819'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-list', 'pipeline_version': '1154'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipe-ynstest', 'pipeline_version': '608'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-with-challengers',
#      'pipeline_version': '119'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'simpleorchestrationpipeline-jcw',
#      'pipeline_version': '526'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-pk3',
#      'pipeline_version': '1852'},
#     'value': [1762288980.294, '225818']},
#    {'metric': {'pipeline': 'rum-assay', 'pipeline_version': '776'},
#     'value': [1762288980.294, '1253591638']},
#    {'metric': {'pipeline': 'simpleorchestrationtutorial',
#      'pipeline_version': '2099'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'preethi2-retail-inv-tracker-edge-obs',
#      'pipeline_version': '196'},
#     'value': [1762288980.294, '738534342']},
#    {'metric': {'pipeline': 'edgebiolabspipeline', 'pipeline_version': '1971'},
#     'value': [1762288980.294, '7775971']},
#    {'metric': {'pipeline': 'llama-cpp', 'pipeline_version': '40'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1095'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-3',
#      'pipeline_version': '915'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama', 'pipeline_version': '1886'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'replica-scaling-static',
#      'pipeline_version': '304'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'sleep-passthrough-pipe',
#      'pipeline_version': '1224'},
#     'value': [1762288980.294, '515881554']},
#    {'metric': {'pipeline': 'whisper-hf-byop-replicatest',
#      'pipeline_version': '336'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'ai-screening', 'pipeline_version': '2311'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacppovms', 'pipeline_version': '2015'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-ynsv6',
#      'pipeline_version': '940'},
#     'value': [1762288980.294, '19798143034']},
#    {'metric': {'pipeline': 'arrow-test-model-pipeline',
#      'pipeline_version': '754'},
#     'value': [1762288980.294, '1877792536']},
#    {'metric': {'pipeline': 'house-price-with-challengers',
#      'pipeline_version': '464'},
#     'value': [1762288980.294, '171121']},
#    {'metric': {'pipeline': 'whisper-hf-byop', 'pipeline_version': '232'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'sidekick-replica-static',
#      'pipeline_version': '311'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-predictor', 'pipeline_version': '189'},
#     'value': [1762288980.294, '225818']},
#    {'metric': {'pipeline': 'logging-pipeline-949260',
#      'pipeline_version': '2264'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '367'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'demandcurvepipeline', 'pipeline_version': '2127'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-cpp', 'pipeline_version': '84'},
#     'value': [1762288980.294, '3772176956']},
#    {'metric': {'pipeline': 'e2e-metrics-test', 'pipeline_version': '1386'},
#     'value': [1762288980.294, '1421061']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-jcw',
#      'pipeline_version': '182'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-jb',
#      'pipeline_version': '729'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1822'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'deployment-status-ccfraud-pipeline-431950',
#      'pipeline_version': '1639'},
#     'value': [1762288980.294, '1928']},
#    {'metric': {'pipeline': 'whisper-hf-byop', 'pipeline_version': '2325'},
#     'value': [1762288980.294, '7882007727']},
#    {'metric': {'pipeline': 'simpleorchestrationtutorial',
#      'pipeline_version': '2343'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-with-challengers',
#      'pipeline_version': '152'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mac-keras-single-io-example-pipeline',
#      'pipeline_version': '181'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-with-challengers',
#      'pipeline_version': '155'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-236223',
#      'pipeline_version': '2188'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'ai-screening', 'pipeline_version': '2310'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'resnetnetpipeline-p10',
#      'pipeline_version': '1928'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'lstm-demand-forecast', 'pipeline_version': '459'},
#     'value': [1762288980.294, '19084360']},
#    {'metric': {'pipeline': 'byop-tinyllama-cutom-vllmedgeyns',
#      'pipeline_version': '1559'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-3',
#      'pipeline_version': '952'},
#     'value': [1762288980.294, '529185057']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb1',
#      'pipeline_version': '1828'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-fm-2', 'pipeline_version': '49'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'safeguards-llamacpp-3', 'pipeline_version': '587'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'simpleorchestrationtutorial-jcw',
#      'pipeline_version': '2279'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'pt-unet', 'pipeline_version': '1865'},
#     'value': [1762288980.294, '62225995']},
#    {'metric': {'pipeline': 'sleep-passthrough-pipe',
#      'pipeline_version': '1220'},
#     'value': [1762288980.294, '515881554']},
#    {'metric': {'pipeline': 'retail-inv-tracker-jetson',
#      'pipeline_version': '496'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacppovms', 'pipeline_version': '2016'},
#     'value': [1762288980.294, '3797551676']},
#    {'metric': {'pipeline': 'logging-pipeline-702016',
#      'pipeline_version': '2237'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1087'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'edgebiolabspipeline', 'pipeline_version': '1477'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-jcw',
#      'pipeline_version': '739'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-8b', 'pipeline_version': '85'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-arm', 'pipeline_version': '745'},
#     'value': [1762288980.294, '3770507836']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag', 'pipeline_version': '1806'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-jcw',
#      'pipeline_version': '933'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'crashy-pipeline', 'pipeline_version': '2303'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1168'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-packaging-python-fail-646204',
#      'pipeline_version': '1398'},
#     'value': [1762288980.294, '512011018']},
#    {'metric': {'pipeline': 'rx-gender-pipeline', 'pipeline_version': '517'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-pipeline', 'pipeline_version': '1074'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'demandcurvepipeline', 'pipeline_version': '2293'},
#     'value': [1762288980.294, '1051733230']},
#    {'metric': {'pipeline': 'llama-openai', 'pipeline_version': '1753'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'bench-aloha-pipeline', 'pipeline_version': '321'},
#     'value': [1762288980.294, '1421061']},
#    {'metric': {'pipeline': 'deploy-specific-version-434108',
#      'pipeline_version': '1643'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb',
#      'pipeline_version': '1783'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-375742',
#      'pipeline_version': '2261'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'replica-scaling-static',
#      'pipeline_version': '301'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'resnetnetpipeline', 'pipeline_version': '524'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-new-pipe-dyn',
#      'pipeline_version': '2090'},
#     'value': [1762288980.294, '7088477742']},
#    {'metric': {'pipeline': 'edge-pipeline', 'pipeline_version': '950'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'rx-gender-pipeline', 'pipeline_version': '521'},
#     'value': [1762288980.294, '85156557']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo-2',
#      'pipeline_version': '1340'},
#     'value': [1762288980.294, '19798143034']},
#    {'metric': {'pipeline': 'e2e-metrics-test', 'pipeline_version': '847'},
#     'value': [1762288980.294, '1421061']},
#    {'metric': {'pipeline': 'test-pipeline', 'pipeline_version': '275'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'rag-pipeline', 'pipeline_version': '1036'},
#     'value': [1762288980.294, '9010563378']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs',
#      'pipeline_version': '56'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'resnetnetpipeline', 'pipeline_version': '567'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'deploy-specific-version-434108',
#      'pipeline_version': '1641'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1078'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'hf-summarization-pipeline',
#      'pipeline_version': '1922'},
#     'value': [1762288980.294, '9290701800']},
#    {'metric': {'pipeline': 'deployment-status-ccfraud-pipeline-894029',
#      'pipeline_version': '1296'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'test-pipeline', 'pipeline_version': '274'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo1',
#      'pipeline_version': '1249'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '373'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop-jcw', 'pipeline_version': '667'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-fm-2', 'pipeline_version': '164'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'deployment-status-ccfraud-pipeline-669117',
#      'pipeline_version': '2180'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-1',
#      'pipeline_version': '896'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-389182',
#      'pipeline_version': '2235'},
#     'value': [1762288980.294, '1928']},
#    {'metric': {'pipeline': 'tinyllama-openai-error1',
#      'pipeline_version': '1773'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'e2e-metrics-test', 'pipeline_version': '1351'},
#     'value': [1762288980.294, '1421061']},
#    {'metric': {'pipeline': 'retail-inv-cuda', 'pipeline_version': '1994'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop', 'pipeline_version': '226'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo1',
#      'pipeline_version': '1247'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-pipeline', 'pipeline_version': '1515'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-pipeline', 'pipeline_version': '963'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '395'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'yolo8demonstration', 'pipeline_version': '1861'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'passthrough-vc-test', 'pipeline_version': '268'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-byop-jcw', 'pipeline_version': '352'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'ab-testing-pipeline-931264',
#      'pipeline_version': '1294'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-egde-yns1',
#      'pipeline_version': '1597'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-list', 'pipeline_version': '1179'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial',
#      'pipeline_version': '1902'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamavllm', 'pipeline_version': '561'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-conversion-pytorch-multi-io-pipeline-799130',
#      'pipeline_version': '1617'},
#     'value': [1762288980.294, '12211']},
#    {'metric': {'pipeline': 'whisper-hf-byop', 'pipeline_version': '208'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'demandcurvepipeline', 'pipeline_version': '2132'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-with-challengers',
#      'pipeline_version': '117'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'safeguards-llamacpp-3', 'pipeline_version': '585'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'vgg16-clustering-pipeline',
#      'pipeline_version': '408'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-278379',
#      'pipeline_version': '2210'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-predictor', 'pipeline_version': '108'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-inline-replacement-demon',
#      'pipeline_version': '539'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-fm-2', 'pipeline_version': '100'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'crashy-pipeline', 'pipeline_version': '2300'},
#     'value': [1762288980.294, '525865686']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo',
#      'pipeline_version': '1337'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-532802',
#      'pipeline_version': '1638'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'deploy-specific-version-751387',
#      'pipeline_version': '1304'},
#     'value': [1762288980.294, '111269']},
#    {'metric': {'pipeline': 'resnet-pipeline', 'pipeline_version': '544'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byopllamacpp-safeguards-pegasi-single-2',
#      'pipeline_version': '649'},
#     'value': [1762288980.294, '3796733804']},
#    {'metric': {'pipeline': 'keras-sequential-single-io',
#      'pipeline_version': '2059'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb2',
#      'pipeline_version': '2011'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-yns1', 'pipeline_version': '875'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb',
#      'pipeline_version': '1722'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-predictor', 'pipeline_version': '150'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-openai', 'pipeline_version': '1694'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'yolo8demonstration-openvino',
#      'pipeline_version': '1940'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-list-arm',
#      'pipeline_version': '2112'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-arm-jet', 'pipeline_version': '2003'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1135'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'vllm-pipeline-shadow', 'pipeline_version': '1429'},
#     'value': [1762288980.294, '19798143034']},
#    {'metric': {'pipeline': 'resnetnetpipeline-benchp10',
#      'pipeline_version': '1227'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byop-vllm-vanilla', 'pipeline_version': '1407'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-ya', 'pipeline_version': '214'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-list', 'pipeline_version': '1159'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo',
#      'pipeline_version': '1334'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byopllamacpp', 'pipeline_version': '605'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '374'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-egde-yns1',
#      'pipeline_version': '1602'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1712'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mitch-edge-20250718', 'pipeline_version': '1995'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1080'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb',
#      'pipeline_version': '1827'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'ab-testing-pipeline-721493',
#      'pipeline_version': '1650'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb1',
#      'pipeline_version': '1837'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'multi-io-example', 'pipeline_version': '852'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'preethi-orch-scale-pipe',
#      'pipeline_version': '201'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whse-c-demand-forecast',
#      'pipeline_version': '444'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'alohapipelinejch', 'pipeline_version': '623'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'simpleorchpipeline', 'pipeline_version': '161'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'aloha-pipeline', 'pipeline_version': '1925'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-jcw',
#      'pipeline_version': '507'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mac-keras-single-io-example-pipeline',
#      'pipeline_version': '2337'},
#     'value': [1762288980.294, '2393439193']},
#    {'metric': {'pipeline': 'whisper-hf-byop-test', 'pipeline_version': '240'},
#     'value': [1762288980.294, '4459635887']},
#    {'metric': {'pipeline': 'hf-zero-shot-classification-jb',
#      'pipeline_version': '808'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-openai', 'pipeline_version': '1742'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '2161'},
#     'value': [1762288980.294, '2062138375']},
#    {'metric': {'pipeline': 'vgg16-clustering-pipeline',
#      'pipeline_version': '2330'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'simpleorchestrationtutorial',
#      'pipeline_version': '2141'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'bench-big-arrays-pipeline',
#      'pipeline_version': '1012'},
#     'value': [1762288980.294, '608157399']},
#    {'metric': {'pipeline': 'pk-resident-signal-staging-pipeline',
#      'pipeline_version': '2277'},
#     'value': [1762288980.294, '1108593958']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs',
#      'pipeline_version': '1468'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'safeguardsdemopipe', 'pipeline_version': '600'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '2113'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '391'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1711'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'vllm-double-replicas', 'pipeline_version': '1441'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-openvino1',
#      'pipeline_version': '1877'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-332650',
#      'pipeline_version': '2218'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'recommender-ab-test', 'pipeline_version': '491'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-packaging-keras-multi-io-pipeline-310172',
#      'pipeline_version': '1581'},
#     'value': [1762288980.294, '2225629123']},
#    {'metric': {'pipeline': 'whisper-hf-byop-testshared2',
#      'pipeline_version': '286'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs',
#      'pipeline_version': '59'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb',
#      'pipeline_version': '1786'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'passthrough-vc-fixed-shape-tensor',
#      'pipeline_version': '257'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-532802',
#      'pipeline_version': '1637'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-327896',
#      'pipeline_version': '2061'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-839648',
#      'pipeline_version': '2217'},
#     'value': [1762288980.294, '111269']},
#    {'metric': {'pipeline': 'llama-pipe-3', 'pipeline_version': '1008'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-fm-2', 'pipeline_version': '176'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mac-keras-single-io-p1',
#      'pipeline_version': '572'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-968262',
#      'pipeline_version': '2255'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-arm', 'pipeline_version': '818'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1139'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'arrow-test-model-pipeline',
#      'pipeline_version': '753'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'simpleorchestrationtutorial-jcw',
#      'pipeline_version': '2068'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama3-8b-instruct-llamacpp-v1',
#      'pipeline_version': '65'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-cpp', 'pipeline_version': '1382'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop', 'pipeline_version': '235'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipe-ynstest', 'pipeline_version': '607'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-566299',
#      'pipeline_version': '2247'},
#     'value': [1762288980.294, '1928']},
#    {'metric': {'pipeline': 'whisper-byop-jcw', 'pipeline_version': '564'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-3dot1-8b-pipe', 'pipeline_version': '2035'},
#     'value': [1762288980.294, '19826190394']},
#    {'metric': {'pipeline': 'house-price-with-challengers',
#      'pipeline_version': '113'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-predictor-drift',
#      'pipeline_version': '185'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mac-keras-single-io-example-pipeline',
#      'pipeline_version': '1'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-5',
#      'pipeline_version': '1149'},
#     'value': [1762288980.294, '529185057']},
#    {'metric': {'pipeline': 'rag-pipeline', 'pipeline_version': '1031'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-pipeline', 'pipeline_version': '1957'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-openai', 'pipeline_version': '1748'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'vgg16-clustering-pipeline',
#      'pipeline_version': '2329'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial',
#      'pipeline_version': '1944'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'alohapipeline', 'pipeline_version': '383'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'keras-sequential-single-io-jb',
#      'pipeline_version': '2125'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-jb', 'pipeline_version': '13'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs',
#      'pipeline_version': '1456'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-594544',
#      'pipeline_version': '1290'},
#     'value': [1762288980.294, '111269']},
#    {'metric': {'pipeline': 'alohapipeline', 'pipeline_version': '620'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-list', 'pipeline_version': '1153'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'sleep-passthrough-pipe',
#      'pipeline_version': '1532'},
#     'value': [1762288980.294, '515973714']},
#    {'metric': {'pipeline': 'house-price-predictor', 'pipeline_version': '461'},
#     'value': [1762288980.294, '225818']},
#    {'metric': {'pipeline': 'house-price-predictor', 'pipeline_version': '111'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'keras-sequential-single-io',
#      'pipeline_version': '549'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'e2e-metrics-test', 'pipeline_version': '1369'},
#     'value': [1762288980.294, '1421061']},
#    {'metric': {'pipeline': 'logging-pipeline-446586',
#      'pipeline_version': '2186'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop-jcw', 'pipeline_version': '1695'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'hotswap-vllm', 'pipeline_version': '1493'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-pipe', 'pipeline_version': '983'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-with-challengers',
#      'pipeline_version': '462'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag', 'pipeline_version': '1835'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-pipe-3', 'pipeline_version': '1569'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'sleep-passthrough-pipe',
#      'pipeline_version': '1188'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop', 'pipeline_version': '2324'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-pipe-3', 'pipeline_version': '1565'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tiny-llama-cuda-demo-pipe',
#      'pipeline_version': '1691'},
#     'value': [1762288980.294, '8893653991']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '418'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byopllamacpp', 'pipeline_version': '604'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-conversion-xgboost-booster-pipeline-324973',
#      'pipeline_version': '1620'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-153932',
#      'pipeline_version': '2203'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-yns1', 'pipeline_version': '876'},
#     'value': [1762288980.294, '7141867625']},
#    {'metric': {'pipeline': 'vgg16-clustering-pipeline',
#      'pipeline_version': '2328'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '2280'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-205619',
#      'pipeline_version': '1215'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'shadow-pipeline-554344',
#      'pipeline_version': '1652'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama3-8b-instruct-llamacpp-t4',
#      'pipeline_version': '72'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'vllm-double-replicas', 'pipeline_version': '1439'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'alohapipeline-jcw', 'pipeline_version': '292'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-openvino-frcnn',
#      'pipeline_version': '2047'},
#     'value': [1762288980.294, '167496949']},
#    {'metric': {'pipeline': 'scale-test-cp', 'pipeline_version': '54'},
#     'value': [1762288980.294, '3617665970']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-1',
#      'pipeline_version': '910'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-inline-replacement-demon',
#      'pipeline_version': '538'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'test-viability-pipeline',
#      'pipeline_version': '364'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-548655',
#      'pipeline_version': '1632'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mac-keras-single-io-example-pipeline',
#      'pipeline_version': '810'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byop-tinyllama-cutom-vllm',
#      'pipeline_version': '988'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-fm-2', 'pipeline_version': '223'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-yns1', 'pipeline_version': '887'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'demandcurvepipeline', 'pipeline_version': '2133'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-predictor', 'pipeline_version': '460'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag', 'pipeline_version': '1812'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1655'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'shadow-pipeline-880880',
#      'pipeline_version': '1286'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag-cb',
#      'pipeline_version': '1740'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-conversion-pytorch-multi-io-pipeline-799130',
#      'pipeline_version': '1616'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1800'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-packaging-keras-multi-io-pipeline-517349',
#      'pipeline_version': '1578'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'simpleorchestrationpipeline-jcw',
#      'pipeline_version': '179'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-with-challengers',
#      'pipeline_version': '157'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'redeploy-ccfraud-pipeline-198252',
#      'pipeline_version': '1301'},
#     'value': [1762288980.294, '1928']},
#    {'metric': {'pipeline': 'logging-pipeline-839648',
#      'pipeline_version': '2215'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo-swap1',
#      'pipeline_version': '1506'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mac-keras-single-io-example-pipeline',
#      'pipeline_version': '811'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'alohapipeline-imp', 'pipeline_version': '511'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamavllm', 'pipeline_version': '558'},
#     'value': [1762288980.294, '13221146439']},
#    {'metric': {'pipeline': 'retail-inv-openvino', 'pipeline_version': '2039'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama', 'pipeline_version': '1980'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'hf-summarization-pipeline',
#      'pipeline_version': '1920'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1106'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs-2',
#      'pipeline_version': '12'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'safeguardsdemopipe', 'pipeline_version': '602'},
#     'value': [1762288980.294, '9751444190']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-594544',
#      'pipeline_version': '1289'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'sidekick-replica-static',
#      'pipeline_version': '315'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'pt-unet', 'pipeline_version': '1480'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1699'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '392'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '2105'},
#     'value': [1762288980.294, '9238330440']},
#    {'metric': {'pipeline': 'auto-conversion-xgboost-classification-pipeline-112261',
#      'pipeline_version': '1618'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'alohapipeline-jcw', 'pipeline_version': '663'},
#     'value': [1762288980.294, '1423137']},
#    {'metric': {'pipeline': 'scale-test-jb', 'pipeline_version': '19'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'python-onnx-pipeline', 'pipeline_version': '1263'},
#     'value': [1762288980.294, '1031763660']},
#    {'metric': {'pipeline': 'dlrm-click-prediction', 'pipeline_version': '992'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-31-8b-vllm-egde',
#      'pipeline_version': '1518'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-conversion-pytorch-single-io-pipeline-355420',
#      'pipeline_version': '1615'},
#     'value': [1762288980.294, '7303']},
#    {'metric': {'pipeline': 'mac-keras-single-io-p1',
#      'pipeline_version': '576'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-hf-summarization',
#      'pipeline_version': '1978'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'rum-assay-nan', 'pipeline_version': '893'},
#     'value': [1762288980.294, '1373102520']},
#    {'metric': {'pipeline': 'llama-openai', 'pipeline_version': '1756'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mac-keras-single-io-example-pipeline',
#      'pipeline_version': '282'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-663217',
#      'pipeline_version': '1648'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop', 'pipeline_version': '209'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-byop-jcw', 'pipeline_version': '357'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-byop-jcw', 'pipeline_version': '353'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-observability-pipeline',
#      'pipeline_version': '1898'},
#     'value': [1762288980.294, '111269']},
#    {'metric': {'pipeline': 'scale-test-ya', 'pipeline_version': '213'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-850802',
#      'pipeline_version': '2207'},
#     'value': [1762288980.294, '1928']},
#    {'metric': {'pipeline': 'keras-sequential-single-io-openvino',
#      'pipeline_version': '1934'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byop-tinyllama-demo-yns2',
#      'pipeline_version': '869'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'demandcurvepipeline', 'pipeline_version': '2159'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs',
#      'pipeline_version': '4'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-openai', 'pipeline_version': '1751'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'replica-scaling-static',
#      'pipeline_version': '303'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tiny-llama-cuda-demo-pipe',
#      'pipeline_version': '1607'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byopllamacpp-safeguards-pegasi-single-3',
#      'pipeline_version': '651'},
#     'value': [1762288980.294, '3796733894']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial',
#      'pipeline_version': '436'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mitch-edge-20250718-b',
#      'pipeline_version': '1998'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1659'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1119'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'image-pipeline-fixed-arr',
#      'pipeline_version': '1136'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'test-pipeline', 'pipeline_version': '284'},
#     'value': [1762288980.294, '47145045']},
#    {'metric': {'pipeline': 'edgebiolabspipeline', 'pipeline_version': '1963'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'shadow-pipeline-880880',
#      'pipeline_version': '1287'},
#     'value': [1762288980.294, '113197']},
#    {'metric': {'pipeline': 'summarizer-listener', 'pipeline_version': '476'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-fm-2', 'pipeline_version': '57'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-hf-summarization',
#      'pipeline_version': '1975'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-pipe-jb', 'pipeline_version': '1413'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'python-onnx-pipeline', 'pipeline_version': '1254'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'e2e-metrics-test', 'pipeline_version': '1376'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1709'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'xgb-ranker-pipeline', 'pipeline_version': '757'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-cpp', 'pipeline_version': '44'},
#     'value': [1762288980.294, '3772176956']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-1',
# ...
#      'pipeline_version': '1342'},
#     'value': [1762288980.294, '19798143034']},
#    {'metric': {'pipeline': 'whisper-byop-jcw', 'pipeline_version': '614'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'safeguards-llamacpp-3', 'pipeline_version': '588'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-pipeline', 'pipeline_version': '946'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'yolo8demonstration-openvino',
#      'pipeline_version': '1939'},
#     'value': [1762288980.294, '12823491']},
#    {'metric': {'pipeline': 'llama-pipe--jb', 'pipeline_version': '1404'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'ab-testing-pipeline-931264',
#      'pipeline_version': '1295'},
#     'value': [1762288980.294, '2327']},
#    {'metric': {'pipeline': 'auto-packaging-byop-157979',
#      'pipeline_version': '1626'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-pipe-3', 'pipeline_version': '1007'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-jb', 'pipeline_version': '629'},
#     'value': [1762288980.294, '7059601261']},
#    {'metric': {'pipeline': 'hf-zero-shot-classification-jcw',
#      'pipeline_version': '657'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1066'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'byop-tinyllama-demo-yns2',
#      'pipeline_version': '868'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop-testshared1',
#      'pipeline_version': '247'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-fixed-arr',
#      'pipeline_version': '1124'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-demo1',
#      'pipeline_version': '1253'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'hf-feature-extraction-pipeline-new-v1',
#      'pipeline_version': '428'},
#     'value': [1762288980.294, '5914817408']},
#    {'metric': {'pipeline': 'pk-resident-signal-staging-pipeline',
#      'pipeline_version': '2274'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs',
#      'pipeline_version': '1458'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop-jcw', 'pipeline_version': '289'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byop-vllm-vanilla', 'pipeline_version': '1402'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'safeguards-llamacpp-2', 'pipeline_version': '583'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'nostart-pipe', 'pipeline_version': '1645'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1734'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-list', 'pipeline_version': '1174'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-yns1', 'pipeline_version': '872'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byop-tinyllama-cutom-vllmedge',
#      'pipeline_version': '1556'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-byop-jcw', 'pipeline_version': '611'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byop-tinyllama-cutom-vllmedgeyns',
#      'pipeline_version': '1595'},
#     'value': [1762288980.294, '11392345928']},
#    {'metric': {'pipeline': 'whisper-hf-byop', 'pipeline_version': '125'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs',
#      'pipeline_version': '167'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama3', 'pipeline_version': '1592'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'shadowimagepipelinetest',
#      'pipeline_version': '569'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-3',
#      'pipeline_version': '917'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-pipeline', 'pipeline_version': '1715'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'deploy-specific-version-434108',
#      'pipeline_version': '1644'},
#     'value': [1762288980.294, '1928']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1070'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'mitch-edge-20250718', 'pipeline_version': '1996'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-dynbatchedge1',
#      'pipeline_version': '837'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-dynbatchedge1',
#      'pipeline_version': '829'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '894'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'deploy-specific-version-737646',
#      'pipeline_version': '1279'},
#     'value': [1762288980.294, '111269']},
#    {'metric': {'pipeline': 'llama3-8b-instruct-llamacpp-v1',
#      'pipeline_version': '68'},
#     'value': [1762288980.294, '7066974073']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1122'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '1726'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-fixed-arr',
#      'pipeline_version': '1112'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag', 'pipeline_version': '1796'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'replace-model-ccfraud-pipeline-374815',
#      'pipeline_version': '1308'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'alohapipelinejch', 'pipeline_version': '624'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'architecture-demonstration-arm',
#      'pipeline_version': '1909'},
#     'value': [1762288980.294, '2460898280']},
#    {'metric': {'pipeline': 'house-price-predictor-drift',
#      'pipeline_version': '186'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1050'},
#     'value': [1762288980.294, '529186453']},
#    {'metric': {'pipeline': 'resident-signal-staging-pipeline',
#      'pipeline_version': '2172'},
#     'value': [1762288980.294, '1108594593']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1142'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'resnetnetpipeline-benchp10',
#      'pipeline_version': '1951'},
#     'value': [1762288980.294, '167496949']},
#    {'metric': {'pipeline': 'preethi-retail-inv-tracker-edge-obs',
#      'pipeline_version': '48'},
#     'value': [1762288980.294, '738534342']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag', 'pipeline_version': '1792'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-inline-replacement-demon',
#      'pipeline_version': '1871'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-byop', 'pipeline_version': '227'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'python-onnx-pipeline', 'pipeline_version': '1266'},
#     'value': [1762288980.294, '1031763660']},
#    {'metric': {'pipeline': 'assay-demo-tutorial', 'pipeline_version': '832'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'deploy-specific-version-737646',
#      'pipeline_version': '1278'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs',
#      'pipeline_version': '381'},
#     'value': [1762288980.294, '738534342']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag', 'pipeline_version': '1674'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs',
#      'pipeline_version': '168'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-with-challengers',
#      'pipeline_version': '156'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-predictor', 'pipeline_version': '140'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-ynsv5',
#      'pipeline_version': '936'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'cgo-multi-step-pipeline',
#      'pipeline_version': '2307'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-new-pipe-dyn',
#      'pipeline_version': '2089'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-jetson',
#      'pipeline_version': '529'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mock-viability-pipeline',
#      'pipeline_version': '396'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'alohapipeline', 'pipeline_version': '1195'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'retail-inv-tracker-edge-obs',
#      'pipeline_version': '61'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama3-8b-instruct-llamacpp3',
#      'pipeline_version': '81'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-error',
#      'pipeline_version': '1768'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byopllamacpp', 'pipeline_version': '634'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-list', 'pipeline_version': '1151'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'byop-tinyllama-demo-yns',
#      'pipeline_version': '859'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-c1000',
#      'pipeline_version': '1343'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'safeguards-llamacpp-2', 'pipeline_version': '414'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-pipeline-classification-cybersecurity',
#      'pipeline_version': '1231'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-jb', 'pipeline_version': '6'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-pk',
#      'pipeline_version': '1776'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag', 'pipeline_version': '1663'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'scale-test-fm-2', 'pipeline_version': '52'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'vllm-pipeline-shadow', 'pipeline_version': '1426'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-dynbatchedge',
#      'pipeline_version': '828'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'byop-tinyllama-cutom-vllmedgeynsjb',
#      'pipeline_version': '1600'},
#     'value': [1762288980.294, '11392345928']},
#    {'metric': {'pipeline': 'alohapipeline-jcw', 'pipeline_version': '324'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'replica-scaling-static',
#      'pipeline_version': '306'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'passthrough-vc-fixed-shape-tensor',
#      'pipeline_version': '258'},
#     'value': [1762288980.294, '497154802']},
#    {'metric': {'pipeline': 'parallel-infer-aloha-pipeline-913986',
#      'pipeline_version': '1207'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1054'},
#     'value': [1762288980.294, '529186453']},
#    {'metric': {'pipeline': 'test-viability-pipeline',
#      'pipeline_version': '365'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'data-optimization', 'pipeline_version': '1611'},
#     'value': [1762288980.294, '529389343']},
#    {'metric': {'pipeline': 'cgo-multi-step-pipeline',
#      'pipeline_version': '2290'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'keras-sequential-single-io-jb',
#      'pipeline_version': '2126'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'assay-demonstration-tutorial-pk4',
#      'pipeline_version': '1853'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'shadow-pipeline-961739',
#      'pipeline_version': '1323'},
#     'value': [1762288980.294, '113197']},
#    {'metric': {'pipeline': 'tinyllama-openai-rag', 'pipeline_version': '1670'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-pipe-openvino', 'pipeline_version': '2049'},
#     'value': [1762288980.294, '171121']},
#    {'metric': {'pipeline': 'logging-pipeline-850802',
#      'pipeline_version': '2206'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'nostart-pipe', 'pipeline_version': '1280'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-pipeline', 'pipeline_version': '942'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mac-keras-single-io-p1',
#      'pipeline_version': '580'},
#     'value': [1762288980.294, '2236449753']},
#    {'metric': {'pipeline': 'rum-assay-nan', 'pipeline_version': '880'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-389182',
#      'pipeline_version': '2231'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'edge-pipeline', 'pipeline_version': '947'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'mitch-edge-20250718-b',
#      'pipeline_version': '1997'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'e2e-metrics-test', 'pipeline_version': '1389'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns', 'pipeline_version': '725'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'data-optimization', 'pipeline_version': '1610'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'apiinferenceexamplepipeline',
#      'pipeline_version': '423'},
#     'value': [1762288980.294, '522549193']},
#    {'metric': {'pipeline': 'vgg16-clustering-pipeline',
#      'pipeline_version': '1022'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'xgb-ranker-pipeline', 'pipeline_version': '760'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'logging-pipeline-930939',
#      'pipeline_version': '2191'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1099'},
#     'value': [1762288980.294, '529186423']},
#    {'metric': {'pipeline': 'whisper-hf-byop-jcw', 'pipeline_version': '288'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-3',
#      'pipeline_version': '925'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'tinyllama-openai', 'pipeline_version': '2028'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'auto-packaging-byop-llamacpp-934757',
#      'pipeline_version': '2163'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'house-price-predictor', 'pipeline_version': '112'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'ai-screening', 'pipeline_version': '2297'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'pk-mock-viability-pipeline-3',
#      'pipeline_version': '928'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-openvino3',
#      'pipeline_version': '1896'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llamacpp-pipeyns-arm1', 'pipeline_version': '814'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'llama-31-8b-vllm-egde-yns1',
#      'pipeline_version': '1598'},
#     'value': [1762288980.294, '19804819514']},
#    {'metric': {'pipeline': 'image-pipeline-b64', 'pipeline_version': '1094'},
#     'value': [1762288980.294, '0']},
#    {'metric': {'pipeline': 'whisper-hf-arm', 'pipeline_version': '1850'},
#     'value': [1762288980.294, '0']},
#    ...]}}

# %% [markdown]
# | Get the total size of all the orchestrations by orchestration AND id | `sum by(id, orchestration) (orchestration_bytes)` |

# %%
#| Get the total size of all the pipeline files by pipeline AND pipeline_version | `sum by(id, orchestration) (orchestration_bytes)` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'sum by(id, orchestration) (orchestration_bytes)'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success',
#  'data': {'resultType': 'vector',
#   'result': [{'metric': {'id': 'e1efb74c-079a-4623-813c-ca031ba42467',
#      'orchestration': 'house price orchestration example'},
#     'value': [1762289263.751, '730446531']},
#    {'metric': {'id': '80740d5b-8c27-45f2-a3d9-78a9f42bff6f',
#      'orchestration': 'demand-forecasting-orchestration'},
#     'value': [1762289263.751, '687792709']},
#    {'metric': {'id': '01e89d0f-0488-4e02-89d3-c02ae9400be9'},
#     'value': [1762289263.751, '448441429']},
#    {'metric': {'id': 'acd1ca9c-5f07-4718-9066-2c3f6bc04a89',
#      'orchestration': 'uploadedbytesdemo'},
#     'value': [1762289263.751, '439215189']},
#    {'metric': {'id': 'd02e40ca-0705-4ab9-a88e-5274a3f5c613',
#      'orchestration': 'demand-forecasting-orchestration'},
#     'value': [1762289263.751, '687792709']},
#    {'metric': {'id': '550e1bfa-b916-4aaa-957e-6702cf27b9b2',
#      'orchestration': 'demand-forecasting-orchestration'},
#     'value': [1762289263.751, '687792712']},
#    {'metric': {'id': '261cabaa-60e0-4c1e-bab2-47878bf7c378',
#      'orchestration': 'house price orchestration example'},
#     'value': [1762289263.751, '632152993']},
#    {'metric': {'id': '1b09d0b5-dfa8-45e5-aecd-e65e3530b1e6',
#      'orchestration': 'long-run-testing'},
#     'value': [1762289263.751, '631276065']},
#    {'metric': {'id': '726ec713-be5f-46da-9574-d954ac371848'},
#     'value': [1762289263.751, '502507999']},
#    {'metric': {'id': 'adabbd79-7bdf-45fd-b046-22ce712c8e0c'},
#     'value': [1762289263.751, '448482389']},
#    {'metric': {'id': '54707d23-7a63-4546-894b-0c833bd68bfe',
#      'orchestration': 'apiorchestrationsample_001'},
#     'value': [1762289263.751, '448441365']},
#    {'metric': {'id': 'ba43b474-f408-4e6b-8af2-ecb6d25cb2db',
#      'orchestration': 'house price orchestration example'},
#     'value': [1762289263.751, '3169010371']},
#    {'metric': {'id': 'ae713d20-4566-4f5b-a06b-7c879d984bdd'},
#     'value': [1762289263.751, '502507999']},
#    {'metric': {'id': '1e44f1ac-6dbc-4286-82da-cf5746d44f38',
#      'orchestration': 'long-run-testing'},
#     'value': [1762289263.751, '631255585']},
#    {'metric': {'id': '8177c1d5-380d-48ef-9ff0-8ba69ad4a9e8'},
#     'value': [1762289263.751, '502354399']},
#    {'metric': {'id': '0638cb6e-6877-418e-aaa6-fc8e64f6432e'},
#     'value': [1762289263.751, '531518228']},
#    {'metric': {'id': '655c0bc4-d7a0-4616-a80a-be662d80a7e6',
#      'orchestration': 'house price orchestration example'},
#     'value': [1762289263.751, '503241633']},
#    {'metric': {'id': '8b46bb89-cb38-4d7f-a28f-bb9250aa3367'},
#     'value': [1762289263.751, '537744148']},
#    {'metric': {'id': 'cbabe852-6c14-4687-8367-fa88796ee54e',
#      'orchestration': 'prophet-orc'},
#     'value': [1762289263.751, '519466781']},
#    {'metric': {'id': '881e388c-4f4e-4736-a92c-d9cea6755fad',
#      'orchestration': 'uploadedbytesdemo'},
#     'value': [1762289263.751, '448482389']}]}}

# %% [markdown]
# | Get the plateau topic storage usage by topic name | `topic_bytes{topic="<topic_name>"}` |

# %%
#| Get the total size of all the pipeline files by pipeline AND pipeline_version | `topic_bytes{topic="<topic_name>"}` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'topic_bytes{topic="<topic_name>"}'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success', 'data': {'resultType': 'vector', 'result': []}}

# %%
| Get the used plateau (log) storage | `sum (topic_bytes)` |

# %% [markdown]
# #| Get the total size of all the pipeline files by pipeline AND pipeline_version | `sum (topic_bytes)` |
#
# # this is the URL to get prometheus metrics
# query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"
#
# # Retrieve the token
# headers = wl.auth.auth_header()
#
# # Get the total size of all the pipeline files by pipeline AND pipeline_version
# query = 'sum (topic_bytes)'
#
# #request parameters
# params_rps = {
#     'query': query,
# }
#
# response_rps = requests.get(query_url, headers=headers, params=params_rps)
#
#
# if response_rps.status_code == 200:
#     print("Query Response:")
#     display(response_rps.json())
# else:
#     print("Failed to fetch query response:", response_rps.status_code, response_rps.text)

# %% [markdown]
# | Name |  Parameterized Query |
# |---|---|
# | Total GPU in use by pods resources | `sum(kube_pod_container_resource_limits{resource=~"nvidia_com_gpu\|qualcomm_com_qaic",app_kubernetes_io_instance="wallaroo"})` |

# %%
# | Total GPU in use by pods resources | 
# `sum(kube_pod_container_resource_limits{resource=~"nvidia_com_gpu\|qualcomm_com_qaic",app_kubernetes_io_instance="wallaroo"})` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'sum(kube_pod_container_resource_limits{resource=~"nvidia_com_gpu|qualcomm_com_qaic",app_kubernetes_io_instance="wallaroo"})'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success', 'data': {'resultType': 'vector', 'result': []}}

# %% [markdown]
# | Total GPU allocated in the cluster | `sum(kube_node_status_capacity{resource=~"nvidia_com_gpu\|qualcomm_com_qaic"})` |

# %%
# | Total GPU in use by pods resources | 
# `sum(kube_node_status_capacity{resource=~"nvidia_com_gpu|qualcomm_com_qaic"})` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'sum(kube_node_status_capacity{resource=~"nvidia_com_gpu|qualcomm_com_qaic"})'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success', 'data': {'resultType': 'vector', 'result': []}}

# %% [markdown]
# #### 7 Day Average Queries
#
# The following queries are targeted for average results over a 7 day period.
#
# | Name |  Parameterized Query | Example Query |
# |---|---|---|
# | Memory requests | `avg_over_time(sum(kube_pod_container_resource_requests{resource="memory",app_kubernetes_io_instance="wallaroo"})[7d:])` |

# %%
#| Memory requests | `avg_over_time(sum(kube_pod_container_resource_requests{resource="memory",app_kubernetes_io_instance="wallaroo"})[7d:])` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'avg_over_time(sum(kube_pod_container_resource_requests{resource="memory",app_kubernetes_io_instance="wallaroo"})[7d:])'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success',
#  'data': {'resultType': 'vector',
#   'result': [{'metric': {}, 'value': [1762364329.566, '16282367505.643349']}]}}

# %% [markdown]
# | CPU requests | `avg_over_time(sum(kube_pod_container_resource_requests{resource="cpu",app_kubernetes_io_instance="wallaroo"})[7d:])` |

# %%
#| CPU requests | `avg_over_time(sum(kube_pod_container_resource_requests{resource="cpu",app_kubernetes_io_instance="wallaroo"})[7d:])` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'avg_over_time(sum(kube_pod_container_resource_requests{resource="cpu",app_kubernetes_io_instance="wallaroo"})[7d:])'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success',
#  'data': {'resultType': 'vector',
#   'result': [{'metric': {}, 'value': [1762365221.159, '12.207195960414376']}]}}

# %% [markdown]
# | CPU utilization (percentage) for a given pipeline | `avg_over_time(sum(rate(container_cpu_usage_seconds_total{namespace="<pipeline namespace>"}[5m]))[7d:]) / sum(kube_pod_container_resource_requests{namespace="<pipeline namespace>",resource="cpu"}) * 100` | `avg_over_time(sum(rate(container_cpu_usage_seconds_total{namespace="sample-pipeline-114"}[5m]))[7d:]) / sum(kube_pod_container_resource_requests{namespace="sample-pipeline-114",resource="cpu"}) * 100` |

# %%
#| CPU utilization (percentage) for a given pipeline | `avg_over_time(sum(rate(container_cpu_usage_seconds_total{namespace="<pipeline namespace>"}[5m]))[7d:]) / sum(kube_pod_container_resource_requests{namespace="<pipeline namespace>",resource="cpu"}) * 100` | `avg_over_time(sum(rate(container_cpu_usage_seconds_total{namespace="sample-pipeline-114"}[5m]))[7d:]) / sum(kube_pod_container_resource_requests{namespace="sample-pipeline-114",resource="cpu"}) * 100` |
 

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
#https://autoscale-uat-gcp.wallaroo.dev/v1/api/pipelines/infer/qualcomm-rag-523/qualcomm-rag
query = 'avg_over_time(sum(rate(container_cpu_usage_seconds_total{namespace="vgg16-clustering-pipeline-65"}[5m]))[7d:]) / sum(kube_pod_container_resource_requests{namespace="vgg16-clustering-pipeline-65",resource="cpu"}) * 100'


#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success',
#  'data': {'resultType': 'vector',
#   'result': [{'metric': {}, 'value': [1762374982.49, '1.027024147239488']}]}}

# %% [markdown]
# | Memory utilization (percentage) | `avg_over_time(sum(container_memory_usage_bytes{namespace="<pipeline namespace>"})[7d:]) / sum(kube_pod_container_resource_requests{namespace="<pipeline namespace>", resource="memory"}) * 100` | `avg_over_time(sum(container_memory_usage_bytes{namespace="sample-pipeline-114"})[7d:]) / sum(kube_pod_container_resource_requests{namespace="sample-pipeline-114", resource="memory"}) * 100` |

# %%
#| Memory utilization (percentage) | `avg_over_time(sum(container_memory_usage_bytes{namespace="qualcomm-rag-523"})[7d:]) / sum(kube_pod_container_resource_requests{namespace="qualcomm-rag-523", resource="memory"}) * 100` |

# this is the URL to get prometheus metrics
query_url = f"{wl.api_endpoint}/v1/metrics/api/v1/query"

# Retrieve the token 
headers = wl.auth.auth_header()

# Get the total size of all the pipeline files by pipeline AND pipeline_version
query = 'avg_over_time(sum(container_memory_usage_bytes{namespace="vgg16-clustering-pipeline-65"})[7d:]) / sum(kube_pod_container_resource_requests{namespace="vgg16-clustering-pipeline-65", resource="memory"}) * 100'

#request parameters
params_rps = {
    'query': query,
}

response_rps = requests.get(query_url, headers=headers, params=params_rps)


if response_rps.status_code == 200:
    print("Query Response:")
    display(response_rps.json())
else:
    print("Failed to fetch query response:", response_rps.status_code, response_rps.text)
# Out:
# Query Response:
# {'status': 'success',
#  'data': {'resultType': 'vector',
#   'result': [{'metric': {}, 'value': [1762375000.599, '33.77326707856905']}]}}
